# %%
# !unzip Dimitri.zip -d data/Dimitri
# Out:
# Archive:  Dimitri.zip
#   inflating: data/Dimitri/PXL_20251116_075638277.jpg
#   inflating: data/Dimitri/PXL_20251116_075644657.jpg
#   inflating: data/Dimitri/PXL_20251116_075634346.jpg
#   inflating: data/Dimitri/PXL_20251116_075636499.jpg
#   inflating: data/Dimitri/PXL_20251116_075634764.jpg
#   inflating: data/Dimitri/PXL_20251116_075643935.jpg
#   inflating: data/Dimitri/PXL_20251116_075642045.jpg
#   inflating: data/Dimitri/PXL_20251116_075637463.jpg
#   inflating: data/Dimitri/PXL_20251116_075641192.jpg
#   inflating: data/Dimitri/PXL_20251116_075640372.jpg
#   inflating: data/Dimitri/PXL_20251116_075643229.jpg
#   inflating: data/Dimitri/PXL_20251116_075635231.jpg
#   inflating: data/Dimitri/PXL_20251116_075641665.jpg
#   inflating: data/Dimitri/PXL_20251116_075633195.jpg
#   inflating: data/Dimitri/PXL_20251116_075635622.jpg
#   inflating: data/Dimitri/PXL_20251116_075637865.jpg
#   inflating: data/Dimitri/PXL_20251116_075640891.jpg
#   inflating: data/Dimitri/PXL_20251116_075639313.jpg
#   inflating: data/Dimitri/PXL_20251116_075636991.jpg
#   inflating: data/Dimitri/PXL_20251116_075644344.jpg
#   inflating: data/Dimitri/PXL_20251116_075642811.jpg
#   inflating: data/Dimitri/PXL_20251116_075643626.jpg
#   inflating: data/Dimitri/PXL_20251116_075642445.jpg
#   inflating: data/Dimitri/PXL_20251116_075638800.jpg
#   inflating: data/Dimitri/PXL_20251116_075639833.jpg

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

from sklearn.utils import class_weight

np.random.seed(42)
tf.random.set_seed(42)

IMG_HEIGHT = 224
IMG_WIDTH = 224
BATCH_SIZE = 8
EPOCHS = 100
DATA_DIR = './data'


def create_cnn_model(num_classes=3):
    """
    Create a CNN model for face classification trained from scratch.

    Architecture:
    - 3 convolutional blocks with batch normalization and dropout
    - Global average pooling layer
    - 1 dense layer with dropout
    - Softmax output layer

    Args:
        num_classes: Number of output classes

    Returns:
        Compiled Keras Sequential model
    """
    model = keras.Sequential([
        layers.Conv2D(32, (3, 3), padding='same', activation='relu',
                     input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.2),

        layers.Conv2D(64, (3, 3), padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.2),

        layers.Conv2D(128, (3, 3), padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.3),

        layers.GlobalAveragePooling2D(),

        layers.Dense(128, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.4),

        layers.Dense(num_classes, activation='softmax')
    ])

    return model


def prepare_data(data_dir):
    """
    Prepare training and validation data generators with augmentation.

    Applies moderate data augmentation to training set including rotation,
    shifts, flips, and zoom. Validation set only receives normalization.

    Args:
        data_dir: Path to directory containing class subdirectories

    Returns:
        Tuple of (train_generator, val_generator)
    """
    train_datagen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=15,
        width_shift_range=0.15,
        height_shift_range=0.15,
        horizontal_flip=True,
        zoom_range=0.15,
        fill_mode='nearest',
        validation_split=0.2
    )

    val_datagen = ImageDataGenerator(
        rescale=1./255,
        validation_split=0.2
    )

    train_generator = train_datagen.flow_from_directory(
        data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        subset='training',
        shuffle=True
    )

    val_generator = val_datagen.flow_from_directory(
        data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        subset='validation',
        shuffle=False
    )

    return train_generator, val_generator


def plot_training_history(history, save_path='training_history.png'):
    """
    Plot and save training and validation accuracy and loss curves.

    Args:
        history: Keras History object from model.fit()
        save_path: Path to save the plot image
    """
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))

    axes[0].plot(history.history['accuracy'], label='Train Accuracy')
    axes[0].plot(history.history['val_accuracy'], label='Val Accuracy')
    axes[0].set_title('Model Accuracy')
    axes[0].set_xlabel('Epoch')
    axes[0].set_ylabel('Accuracy')
    axes[0].legend()
    axes[0].grid(True)

    axes[1].plot(history.history['loss'], label='Train Loss')
    axes[1].plot(history.history['val_loss'], label='Val Loss')
    axes[1].set_title('Model Loss')
    axes[1].set_xlabel('Epoch')
    axes[1].set_ylabel('Loss')
    axes[1].legend()
    axes[1].grid(True)

    plt.tight_layout()
    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    print(f"Training history plot saved to {save_path}")
    plt.close()


def evaluate_model(model, val_generator):
    """
    Evaluate model performance and generate confusion matrix.

    Prints classification report with precision, recall, and F1-scores.
    Saves confusion matrix visualization.

    Args:
        model: Trained Keras model
        val_generator: Validation data generator

    Returns:
        Tuple of (predictions, true_labels)
    """
    val_generator.reset()
    predictions = model.predict(val_generator, steps=len(val_generator))
    y_pred = np.argmax(predictions, axis=1)
    y_true = val_generator.classes

    class_names = list(val_generator.class_indices.keys())

    print("\nClassification Report:")
    print(classification_report(y_true, y_pred, target_names=class_names))

    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names, yticklabels=class_names)
    plt.title('Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.savefig('confusion_matrix.png', dpi=300, bbox_inches='tight')
    print("Confusion matrix saved to confusion_matrix.png")
    plt.close()

    return y_pred, y_true


def main():
    """
    Main training pipeline for face classification CNN.

    Pipeline:
    1. Load and prepare data with augmentation
    2. Create CNN model
    3. Compile model with Adam optimizer
    4. Train with callbacks (early stopping, learning rate reduction)
    5. Evaluate and save model
    6. Generate visualizations and metrics
    """
    print("=" * 60)
    print("Face Classification CNN - Training From Scratch")
    print("=" * 60)

    if not os.path.exists(DATA_DIR):
        print(f"\nError: Data directory '{DATA_DIR}' not found!")
        print("Please update the DATA_DIR variable with your data path.")
        return

    print(f"\nLoading data from: {DATA_DIR}")
    train_generator, val_generator = prepare_data(DATA_DIR)

    num_classes = len(train_generator.class_indices)
    print(f"\nNumber of classes: {num_classes}")
    print(f"Class names: {list(train_generator.class_indices.keys())}")
    print(f"Training samples: {train_generator.samples}")
    print(f"Validation samples: {val_generator.samples}")

    print("\nCreating custom CNN model...")
    model = create_cnn_model(num_classes)

    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=0.001),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    print("\nModel Summary:")
    model.summary()

    class_weights = class_weight.compute_class_weight(
        'balanced',
        classes=np.unique(train_generator.classes),
        y=train_generator.classes
    )
    class_weight_dict = dict(enumerate(class_weights))

    print(f"\nClass weights (to handle imbalance): {class_weight_dict}")

    callbacks = [
        EarlyStopping(
            monitor='val_loss',
            patience=20,
            restore_best_weights=True,
            verbose=1
        ),
        ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=5,
            min_lr=1e-6,
            verbose=1
        ),
        ModelCheckpoint(
            'best_model.keras',
            monitor='val_accuracy',
            save_best_only=True,
            verbose=1
        )
    ]

    print("\n" + "=" * 60)
    print("Starting training...")
    print("=" * 60)

    history = model.fit(
        train_generator,
        validation_data=val_generator,
        epochs=EPOCHS,
        callbacks=callbacks,
        class_weight=class_weight_dict,
        verbose=1
    )

    plot_training_history(history)

    print("\n" + "=" * 60)
    print("Evaluating model...")
    print("=" * 60)

    evaluate_model(model, val_generator)

    model.save('face_classifier_final.keras')
    print("\nFinal model saved to: face_classifier_final.keras")

    print("\n" + "=" * 60)
    print("Training Complete!")
    print("=" * 60)
    print("\nGenerated files:")
    print("1. best_model.keras - Best model during training")
    print("2. face_classifier_final.keras - Final trained model")
    print("3. training_history.png - Training curves")
    print("4. confusion_matrix.png - Confusion matrix")


if __name__ == "__main__":
    main()
# Out:
# ============================================================
# Face Classification CNN - Training From Scratch
# ============================================================
#
# Loading data from: ./data
# Found 100 images belonging to 3 classes.
# Found 25 images belonging to 3 classes.
#
# Number of classes: 3
# Class names: ['Alexis', 'Dimitri', 'Pallav']
# Training samples: 100
# Validation samples: 25
#
# Creating custom CNN model...
#
# Model Summary:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_22 (Conv2D)              │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_28          │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_14 (MaxPooling2D) │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_20 (Dropout)            │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_23 (Conv2D)              │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_29          │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_15 (MaxPooling2D) │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_21 (Dropout)            │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_24 (Conv2D)              │ (None, 56, 56, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_30          │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_16 (MaxPooling2D) │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_22 (Dropout)            │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_4      │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_31          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_23 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 3)              │           387 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 111,555 (435.76 KB)
#  Trainable params: 110,851 (433.01 KB)
#  Non-trainable params: 704 (2.75 KB)
# Class weights (to handle imbalance): {0: np.float64(0.8333333333333334), 1: np.float64(1.6666666666666667), 2: np.float64(0.8333333333333334)}
#
# ============================================================
# Starting training...
# ============================================================
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 606ms/step - accuracy: 0.8560 - loss: 0.3437
# Epoch 1: val_accuracy improved from -inf to 0.20000, saving model to best_model.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 775ms/step - accuracy: 0.8627 - loss: 0.3320 - val_accuracy: 0.2000 - val_loss: 1.1250 - learning_rate: 0.0010
# Epoch 2/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.9805 - loss: 0.0756
# Epoch 2: val_accuracy improved from 0.20000 to 0.44000, saving model to best_model.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 243ms/step - accuracy: 0.9797 - loss: 0.0758 - val_accuracy: 0.4400 - val_loss: 1.1416 - learning_rate: 0.0010
# Epoch 3/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9157 - loss: 0.2660
# Epoch 3: val_accuracy did not improve from 0.44000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 249ms/step - accuracy: 0.9189 - loss: 0.2577 - val_accuracy: 0.4000 - val_loss: 1.2524 - learning_rate: 0.0010
# Epoch 4/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9747 - loss: 0.0963
# Epoch 4: val_accuracy did not improve from 0.44000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 244ms/step - accuracy: 0.9737 - loss: 0.0971 - val_accuracy: 0.4000 - val_loss: 1.4309 - learning_rate: 0.0010
# Epoch 5/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.9796 - loss: 0.0533
# Epoch 5: val_accuracy did not improve from 0.44000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 240ms/step - accuracy: 0.9782 - loss: 0.0559 - val_accuracy: 0.4000 - val_loss: 1.7445 - learning_rate: 0.0010
# Epoch 6/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.9797 - loss: 0.0354
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 6: val_accuracy did not improve from 0.44000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 238ms/step - accuracy: 0.9797 - loss: 0.0359 - val_accuracy: 0.4000 - val_loss: 2.1199 - learning_rate: 0.0010
# Epoch 7/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9866 - loss: 0.0380
# Epoch 7: val_accuracy did not improve from 0.44000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 233ms/step - accuracy: 0.9869 - loss: 0.0380 - val_accuracy: 0.4000 - val_loss: 2.4498 - learning_rate: 5.0000e-04
# Epoch 8/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9992 - loss: 0.0174
# Epoch 8: val_accuracy did not improve from 0.44000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 241ms/step - accuracy: 0.9986 - loss: 0.0182 - val_accuracy: 0.4000 - val_loss: 2.8257 - learning_rate: 5.0000e-04
# Epoch 9/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9941 - loss: 0.0280
# Epoch 9: val_accuracy did not improve from 0.44000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 251ms/step - accuracy: 0.9938 - loss: 0.0285 - val_accuracy: 0.4000 - val_loss: 3.2841 - learning_rate: 5.0000e-04
# Epoch 10/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.9984 - loss: 0.0180
# Epoch 10: val_accuracy did not improve from 0.44000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 241ms/step - accuracy: 0.9978 - loss: 0.0213 - val_accuracy: 0.4000 - val_loss: 3.5694 - learning_rate: 5.0000e-04
# Epoch 11/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 1.0000 - loss: 0.0095
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 11: val_accuracy did not improve from 0.44000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 240ms/step - accuracy: 1.0000 - loss: 0.0098 - val_accuracy: 0.4000 - val_loss: 3.5235 - learning_rate: 5.0000e-04
# Epoch 12/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.9975 - loss: 0.0162
# Epoch 12: val_accuracy did not improve from 0.44000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 236ms/step - accuracy: 0.9969 - loss: 0.0169 - val_accuracy: 0.4000 - val_loss: 3.8381 - learning_rate: 2.5000e-04
# Epoch 13/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.9821 - loss: 0.0456
# Epoch 13: val_accuracy did not improve from 0.44000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 237ms/step - accuracy: 0.9827 - loss: 0.0445 - val_accuracy: 0.4000 - val_loss: 4.4138 - learning_rate: 2.5000e-04
# Epoch 14/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 1.0000 - loss: 0.0100
# Epoch 14: val_accuracy did not improve from 0.44000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 249ms/step - accuracy: 1.0000 - loss: 0.0100 - val_accuracy: 0.4000 - val_loss: 4.8008 - learning_rate: 2.5000e-04
# Epoch 15/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 1.0000 - loss: 0.0209
# Epoch 15: val_accuracy did not improve from 0.44000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 245ms/step - accuracy: 1.0000 - loss: 0.0217 - val_accuracy: 0.4000 - val_loss: 5.1172 - learning_rate: 2.5000e-04
# Epoch 16/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 1.0000 - loss: 0.0158
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 16: val_accuracy did not improve from 0.44000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 252ms/step - accuracy: 1.0000 - loss: 0.0155 - val_accuracy: 0.4000 - val_loss: 5.3286 - learning_rate: 2.5000e-04
# Epoch 17/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.9694 - loss: 0.0621
# Epoch 17: val_accuracy did not improve from 0.44000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 239ms/step - accuracy: 0.9709 - loss: 0.0601 - val_accuracy: 0.4000 - val_loss: 5.5391 - learning_rate: 1.2500e-04
# Epoch 18/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9887 - loss: 0.0928
# Epoch 18: val_accuracy did not improve from 0.44000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 248ms/step - accuracy: 0.9888 - loss: 0.0902 - val_accuracy: 0.4000 - val_loss: 5.7195 - learning_rate: 1.2500e-04
# Epoch 19/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 1.0000 - loss: 0.0044
# Epoch 19: val_accuracy did not improve from 0.44000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 244ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.4000 - val_loss: 5.8465 - learning_rate: 1.2500e-04
# Epoch 20/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9205 - loss: 0.2119
# Epoch 20: val_accuracy did not improve from 0.44000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 243ms/step - accuracy: 0.9218 - loss: 0.2089 - val_accuracy: 0.4000 - val_loss: 6.0134 - learning_rate: 1.2500e-04
# Epoch 21/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 1.0000 - loss: 0.0166
# Epoch 21: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 21: val_accuracy did not improve from 0.44000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 240ms/step - accuracy: 1.0000 - loss: 0.0167 - val_accuracy: 0.4000 - val_loss: 6.1751 - learning_rate: 1.2500e-04
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Training history plot saved to training_history.png
#
# ============================================================
# Evaluating model...
# ============================================================
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 191ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Alexis       0.00      0.00      0.00        10
#      Dimitri       0.20      1.00      0.33         5
#       Pallav       0.00      0.00      0.00        10
#
#     accuracy                           0.20        25
#    macro avg       0.07      0.33      0.11        25
# weighted avg       0.04      0.20      0.07        25
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Confusion matrix saved to confusion_matrix.png
#
# Final model saved to: face_classifier_final.keras
#
# ============================================================
# Training Complete!
# ============================================================
#
# Generated files:
# 1. best_model.keras - Best model during training
# 2. face_classifier_final.keras - Final trained model
# 3. training_history.png - Training curves
# 4. confusion_matrix.png - Confusion matrix

# %%
# !unzip Pallav.zip -d data/
# Out:
# Archive:  Pallav.zip
#    creating: data/Pallav/
#   inflating: data/Pallav/Pallav_0000_20251117_023337_979091.jpg
#   inflating: data/Pallav/Pallav_0001_20251117_023338_289954.jpg
#   inflating: data/Pallav/Pallav_0002_20251117_023338_619188.jpg
#   inflating: data/Pallav/Pallav_0003_20251117_023338_946614.jpg
#   inflating: data/Pallav/Pallav_0004_20251117_023339_265542.jpg
#   inflating: data/Pallav/Pallav_0005_20251117_023339_588722.jpg
#   inflating: data/Pallav/Pallav_0006_20251117_023339_905977.jpg
#   inflating: data/Pallav/Pallav_0007_20251117_023340_231977.jpg
#   inflating: data/Pallav/Pallav_0008_20251117_023340_549708.jpg
#   inflating: data/Pallav/Pallav_0009_20251117_023340_877651.jpg
#   inflating: data/Pallav/Pallav_0010_20251117_023341_200514.jpg
#   inflating: data/Pallav/Pallav_0011_20251117_023341_525692.jpg
#   inflating: data/Pallav/Pallav_0012_20251117_023341_881212.jpg
#   inflating: data/Pallav/Pallav_0013_20251117_023342_205256.jpg
#   inflating: data/Pallav/Pallav_0014_20251117_023342_528474.jpg
#   inflating: data/Pallav/Pallav_0015_20251117_023342_853575.jpg
#   inflating: data/Pallav/Pallav_0016_20251117_023343_179470.jpg
#   inflating: data/Pallav/Pallav_0017_20251117_023343_497785.jpg
#   inflating: data/Pallav/Pallav_0018_20251117_023343_826786.jpg
#   inflating: data/Pallav/Pallav_0019_20251117_023344_147585.jpg
#   inflating: data/Pallav/Pallav_0020_20251117_023344_468547.jpg
#   inflating: data/Pallav/Pallav_0021_20251117_023344_792260.jpg
#   inflating: data/Pallav/Pallav_0022_20251117_023345_107720.jpg
#   inflating: data/Pallav/Pallav_0023_20251117_023345_430784.jpg
#   inflating: data/Pallav/Pallav_0024_20251117_023345_758339.jpg
#   inflating: data/Pallav/Pallav_0025_20251117_023346_076193.jpg
#   inflating: data/Pallav/Pallav_0026_20251117_023346_401300.jpg
#   inflating: data/Pallav/Pallav_0027_20251117_023346_725043.jpg
#   inflating: data/Pallav/Pallav_0028_20251117_023347_051689.jpg
#   inflating: data/Pallav/Pallav_0029_20251117_023347_370101.jpg
#   inflating: data/Pallav/Pallav_0030_20251117_023347_691912.jpg
#   inflating: data/Pallav/Pallav_0031_20251117_023348_008084.jpg
#   inflating: data/Pallav/Pallav_0032_20251117_023348_382522.jpg
#   inflating: data/Pallav/Pallav_0033_20251117_023348_699919.jpg
#   inflating: data/Pallav/Pallav_0034_20251117_023349_020321.jpg
#   inflating: data/Pallav/Pallav_0035_20251117_023349_343528.jpg
#   inflating: data/Pallav/Pallav_0036_20251117_023349_668915.jpg
#   inflating: data/Pallav/Pallav_0037_20251117_023349_997554.jpg
#   inflating: data/Pallav/Pallav_0038_20251117_023350_317974.jpg
#   inflating: data/Pallav/Pallav_0039_20251117_023350_637132.jpg
#   inflating: data/Pallav/Pallav_0040_20251117_023350_964483.jpg
#   inflating: data/Pallav/Pallav_0041_20251117_023351_283203.jpg
#   inflating: data/Pallav/Pallav_0042_20251117_023351_603127.jpg
#   inflating: data/Pallav/Pallav_0043_20251117_023351_926814.jpg
#   inflating: data/Pallav/Pallav_0044_20251117_023352_256004.jpg
#   inflating: data/Pallav/Pallav_0045_20251117_023352_570178.jpg
#   inflating: data/Pallav/Pallav_0046_20251117_023352_895919.jpg
#   inflating: data/Pallav/Pallav_0047_20251117_023353_225700.jpg
#   inflating: data/Pallav/Pallav_0048_20251117_023353_540371.jpg
#   inflating: data/Pallav/Pallav_0049_20251117_023353_864704.jpg

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from sklearn.utils import class_weight

np.random.seed(42)
tf.random.set_seed(42)

IMG_HEIGHT = 224
IMG_WIDTH = 224
BATCH_SIZE = 8
EPOCHS = 100
DATA_DIR = './data'


def create_transfer_learning_model(num_classes=3):
    """
    Create a transfer learning model using MobileNetV2 pre-trained on ImageNet.

    Uses pre-trained MobileNetV2 as feature extractor with custom classification head.
    The base model starts frozen and can be fine-tuned later.

    Args:
        num_classes: Number of output classes

    Returns:
        Tuple of (model, base_model)
    """
    base_model = keras.applications.MobileNetV2(
        input_shape=(IMG_HEIGHT, IMG_WIDTH, 3),
        include_top=False,
        weights='imagenet'
    )

    base_model.trainable = False

    model = keras.Sequential([
        base_model,
        layers.GlobalAveragePooling2D(),
        layers.Dense(256, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.5),
        layers.Dense(128, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.3),
        layers.Dense(num_classes, activation='softmax')
    ])

    return model, base_model


def prepare_data(data_dir):
    """
    Prepare training and validation data generators with augmentation.

    Applies moderate data augmentation to training set. Validation set
    only receives normalization.

    Args:
        data_dir: Path to directory containing class subdirectories

    Returns:
        Tuple of (train_generator, val_generator)
    """
    train_datagen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=20,
        width_shift_range=0.2,
        height_shift_range=0.2,
        horizontal_flip=True,
        zoom_range=0.2,
        fill_mode='nearest',
        validation_split=0.2
    )

    val_datagen = ImageDataGenerator(
        rescale=1./255,
        validation_split=0.2
    )

    train_generator = train_datagen.flow_from_directory(
        data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        subset='training',
        shuffle=True
    )

    val_generator = val_datagen.flow_from_directory(
        data_dir,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        subset='validation',
        shuffle=False
    )

    return train_generator, val_generator


def plot_training_history(history, save_path='training_history_transfer.png'):
    """
    Plot and save training and validation accuracy and loss curves.

    Args:
        history: Keras History object from model.fit()
        save_path: Path to save the plot image
    """
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))

    axes[0].plot(history.history['accuracy'], label='Train Accuracy')
    axes[0].plot(history.history['val_accuracy'], label='Val Accuracy')
    axes[0].set_title('Model Accuracy')
    axes[0].set_xlabel('Epoch')
    axes[0].set_ylabel('Accuracy')
    axes[0].legend()
    axes[0].grid(True)

    axes[1].plot(history.history['loss'], label='Train Loss')
    axes[1].plot(history.history['val_loss'], label='Val Loss')
    axes[1].set_title('Model Loss')
    axes[1].set_xlabel('Epoch')
    axes[1].set_ylabel('Loss')
    axes[1].legend()
    axes[1].grid(True)

    plt.tight_layout()
    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    print(f"Training history plot saved to {save_path}")
    plt.close()


def evaluate_model(model, val_generator):
    """
    Evaluate model performance and generate confusion matrix.

    Prints classification report with precision, recall, and F1-scores.
    Saves confusion matrix visualization.

    Args:
        model: Trained Keras model
        val_generator: Validation data generator

    Returns:
        Tuple of (predictions, true_labels)
    """
    val_generator.reset()
    predictions = model.predict(val_generator, steps=len(val_generator))
    y_pred = np.argmax(predictions, axis=1)
    y_true = val_generator.classes

    class_names = list(val_generator.class_indices.keys())

    print("\nClassification Report:")
    print(classification_report(y_true, y_pred, target_names=class_names))

    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names, yticklabels=class_names)
    plt.title('Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.savefig('confusion_matrix_transfer.png', dpi=300, bbox_inches='tight')
    print("Confusion matrix saved to confusion_matrix_transfer.png")
    plt.close()

    return y_pred, y_true


def main():
    """
    Main training pipeline for face classification using transfer learning.

    Pipeline:
    1. Load and prepare data with augmentation
    2. Create transfer learning model with frozen base
    3. Train classification head
    4. Unfreeze and fine-tune entire model
    5. Evaluate and save model
    6. Generate visualizations and metrics
    """
    print("=" * 60)
    print("Face Classification - Transfer Learning")
    print("=" * 60)

    if not os.path.exists(DATA_DIR):
        print(f"\nError: Data directory '{DATA_DIR}' not found!")
        print("Please update the DATA_DIR variable with your data path.")
        return

    print(f"\nLoading data from: {DATA_DIR}")
    train_generator, val_generator = prepare_data(DATA_DIR)

    num_classes = len(train_generator.class_indices)
    print(f"\nNumber of classes: {num_classes}")
    print(f"Class names: {list(train_generator.class_indices.keys())}")
    print(f"Training samples: {train_generator.samples}")
    print(f"Validation samples: {val_generator.samples}")

    train_class_counts = np.bincount(train_generator.classes)
    print(f"Training class counts: {dict(zip(train_generator.class_indices.keys(), train_class_counts))}")

    max_count = np.max(train_class_counts)
    class_weights = max_count / train_class_counts
    class_weight_dict = dict(enumerate(class_weights))

    print(f"Class weights: {class_weight_dict}")

    print("\nCreating transfer learning model with MobileNetV2...")
    model, base_model = create_transfer_learning_model(num_classes)

    print("\n" + "=" * 60)
    print("PHASE 1: Training classification head (base frozen)")
    print("=" * 60)

    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=0.001),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    print("\nModel Summary:")
    model.summary()

    callbacks_phase1 = [
        EarlyStopping(
            monitor='val_loss',
            patience=15,
            restore_best_weights=True,
            verbose=1
        ),
        ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=5,
            min_lr=1e-6,
            verbose=1
        ),
        ModelCheckpoint(
            'best_model_transfer_phase1.keras',
            monitor='val_accuracy',
            save_best_only=True,
            verbose=1
        )
    ]

    print("\nTraining classification head...")
    history_phase1 = model.fit(
        train_generator,
        validation_data=val_generator,
        epochs=30,
        callbacks=callbacks_phase1,
        class_weight=class_weight_dict,
        verbose=1
    )

    print("\n" + "=" * 60)
    print("PHASE 2: Fine-tuning (unfreezing base model)")
    print("=" * 60)

    base_model.trainable = True

    fine_tune_at = len(base_model.layers) - 30
    for layer in base_model.layers[:fine_tune_at]:
        layer.trainable = False

    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=1e-5),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    print(f"\nUnfrozen layers: {sum([1 for layer in model.layers if layer.trainable])}")
    print(f"Frozen layers: {sum([1 for layer in model.layers if not layer.trainable])}")

    callbacks_phase2 = [
        EarlyStopping(
            monitor='val_loss',
            patience=20,
            restore_best_weights=True,
            verbose=1
        ),
        ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=7,
            min_lr=1e-7,
            verbose=1
        ),
        ModelCheckpoint(
            'best_model_transfer.keras',
            monitor='val_accuracy',
            save_best_only=True,
            verbose=1
        )
    ]

    print("\nFine-tuning entire model...")
    history_phase2 = model.fit(
        train_generator,
        validation_data=val_generator,
        epochs=EPOCHS,
        callbacks=callbacks_phase2,
        class_weight=class_weight_dict,
        verbose=1
    )

    for key in history_phase1.history.keys():
        history_phase1.history[key].extend(history_phase2.history[key])

    plot_training_history(history_phase1)

    print("\n" + "=" * 60)
    print("Evaluating model...")
    print("=" * 60)

    evaluate_model(model, val_generator)

    model.save('face_classifier_transfer_final.keras')
    print("\nFinal model saved to: face_classifier_transfer_final.keras")

    print("\n" + "=" * 60)
    print("Training Complete!")
    print("=" * 60)
    print("\nGenerated files:")
    print("1. best_model_transfer.keras - Best model during training")
    print("2. face_classifier_transfer_final.keras - Final trained model")
    print("3. training_history_transfer.png - Training curves")
    print("4. confusion_matrix_transfer.png - Confusion matrix")


if __name__ == "__main__":
    main()
# Out:
# ============================================================
# Face Classification - Transfer Learning
# ============================================================
#
# Loading data from: ./data
# Found 100 images belonging to 3 classes.
# Found 25 images belonging to 3 classes.
#
# Number of classes: 3
# Class names: ['Alexis', 'Dimitri', 'Pallav']
# Training samples: 100
# Validation samples: 25
# Training class counts: {'Alexis': np.int64(40), 'Dimitri': np.int64(20), 'Pallav': np.int64(40)}
# Class weights: {0: np.float64(1.0), 1: np.float64(2.0), 2: np.float64(1.0)}
#
# Creating transfer learning model with MobileNetV2...
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
#
# ============================================================
# PHASE 1: Training classification head (base frozen)
# ============================================================
#
# Model Summary:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_5      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_32          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_24 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_33          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_25 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 3)              │           387 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,620,739 (10.00 MB)
#  Trainable params: 361,987 (1.38 MB)
#  Non-trainable params: 2,258,752 (8.62 MB)
# Training classification head...
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6544 - loss: 0.9411
# Epoch 1: val_accuracy improved from -inf to 0.96000, saving model to best_model_transfer_phase1.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 60s 3s/step - accuracy: 0.6634 - loss: 0.9171 - val_accuracy: 0.9600 - val_loss: 0.3691 - learning_rate: 0.0010
# Epoch 2/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.9644 - loss: 0.1428
# Epoch 2: val_accuracy did not improve from 0.96000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 244ms/step - accuracy: 0.9627 - loss: 0.1459 - val_accuracy: 0.9600 - val_loss: 0.2282 - learning_rate: 0.0010
# Epoch 3/30
# 12/13 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.9292 - loss: 0.1557
# Epoch 3: val_accuracy did not improve from 0.96000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 264ms/step - accuracy: 0.9322 - loss: 0.1579 - val_accuracy: 0.9600 - val_loss: 0.1389 - learning_rate: 0.0010
# Epoch 4/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9792 - loss: 0.0700
# Epoch 4: val_accuracy improved from 0.96000 to 1.00000, saving model to best_model_transfer_phase1.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 277ms/step - accuracy: 0.9771 - loss: 0.0719 - val_accuracy: 1.0000 - val_loss: 0.0463 - learning_rate: 0.0010
# Epoch 5/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9601 - loss: 0.1562
# Epoch 5: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 252ms/step - accuracy: 0.9601 - loss: 0.1559 - val_accuracy: 1.0000 - val_loss: 0.0374 - learning_rate: 0.0010
# Epoch 6/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.9889 - loss: 0.0332
# Epoch 6: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 240ms/step - accuracy: 0.9876 - loss: 0.0354 - val_accuracy: 0.9600 - val_loss: 0.0492 - learning_rate: 0.0010
# Epoch 7/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.9834 - loss: 0.0786
# Epoch 7: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 238ms/step - accuracy: 0.9839 - loss: 0.0766 - val_accuracy: 0.9600 - val_loss: 0.0714 - learning_rate: 0.0010
# Epoch 8/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 1.0000 - loss: 0.0264
# Epoch 8: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 240ms/step - accuracy: 1.0000 - loss: 0.0267 - val_accuracy: 1.0000 - val_loss: 0.0421 - learning_rate: 0.0010
# Epoch 9/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.9985 - loss: 0.0228
# Epoch 9: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 241ms/step - accuracy: 0.9971 - loss: 0.0252 - val_accuracy: 1.0000 - val_loss: 0.0128 - learning_rate: 0.0010
# Epoch 10/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 1.0000 - loss: 0.0176
# Epoch 10: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 250ms/step - accuracy: 1.0000 - loss: 0.0171 - val_accuracy: 1.0000 - val_loss: 0.0041 - learning_rate: 0.0010
# Epoch 11/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.9827 - loss: 0.0439
# Epoch 11: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 258ms/step - accuracy: 0.9833 - loss: 0.0432 - val_accuracy: 1.0000 - val_loss: 0.0027 - learning_rate: 0.0010
# Epoch 12/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.9838 - loss: 0.0304
# Epoch 12: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 249ms/step - accuracy: 0.9842 - loss: 0.0305 - val_accuracy: 1.0000 - val_loss: 0.0026 - learning_rate: 0.0010
# Epoch 13/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9992 - loss: 0.0113
# Epoch 13: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 235ms/step - accuracy: 0.9986 - loss: 0.0123 - val_accuracy: 1.0000 - val_loss: 0.0020 - learning_rate: 0.0010
# Epoch 14/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 1.0000 - loss: 0.0146
# Epoch 14: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 253ms/step - accuracy: 1.0000 - loss: 0.0156 - val_accuracy: 1.0000 - val_loss: 9.1149e-04 - learning_rate: 0.0010
# Epoch 15/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9859 - loss: 0.0620
# Epoch 15: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 258ms/step - accuracy: 0.9847 - loss: 0.0636 - val_accuracy: 1.0000 - val_loss: 5.8830e-04 - learning_rate: 0.0010
# Epoch 16/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.9866 - loss: 0.0212
# Epoch 16: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 255ms/step - accuracy: 0.9869 - loss: 0.0214 - val_accuracy: 1.0000 - val_loss: 6.6806e-04 - learning_rate: 0.0010
# Epoch 17/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 1.0000 - loss: 0.0346
# Epoch 17: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 254ms/step - accuracy: 1.0000 - loss: 0.0347 - val_accuracy: 1.0000 - val_loss: 7.1372e-04 - learning_rate: 0.0010
# Epoch 18/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.9559 - loss: 0.1512
# Epoch 18: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 239ms/step - accuracy: 0.9548 - loss: 0.1557 - val_accuracy: 1.0000 - val_loss: 0.0040 - learning_rate: 0.0010
# Epoch 19/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 1.0000 - loss: 0.0085
# Epoch 19: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 243ms/step - accuracy: 1.0000 - loss: 0.0088 - val_accuracy: 1.0000 - val_loss: 0.0125 - learning_rate: 0.0010
# Epoch 20/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.8685 - loss: 0.2944
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 20: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 244ms/step - accuracy: 0.8715 - loss: 0.2927 - val_accuracy: 1.0000 - val_loss: 7.1653e-04 - learning_rate: 0.0010
# Epoch 21/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 1.0000 - loss: 0.0146
# Epoch 21: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 251ms/step - accuracy: 1.0000 - loss: 0.0150 - val_accuracy: 1.0000 - val_loss: 7.8582e-04 - learning_rate: 5.0000e-04
# Epoch 22/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 1.0000 - loss: 0.0186
# Epoch 22: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 242ms/step - accuracy: 1.0000 - loss: 0.0182 - val_accuracy: 1.0000 - val_loss: 3.4903e-04 - learning_rate: 5.0000e-04
# Epoch 23/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9975 - loss: 0.0158
# Epoch 23: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 258ms/step - accuracy: 0.9969 - loss: 0.0173 - val_accuracy: 1.0000 - val_loss: 2.9079e-04 - learning_rate: 5.0000e-04
# Epoch 24/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 1.0000 - loss: 0.0417
# Epoch 24: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 253ms/step - accuracy: 1.0000 - loss: 0.0412 - val_accuracy: 1.0000 - val_loss: 1.8610e-04 - learning_rate: 5.0000e-04
# Epoch 25/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 1.0000 - loss: 0.0125
# Epoch 25: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 253ms/step - accuracy: 1.0000 - loss: 0.0125 - val_accuracy: 1.0000 - val_loss: 1.6629e-04 - learning_rate: 5.0000e-04
# Epoch 26/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.9849 - loss: 0.0267
# Epoch 26: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 239ms/step - accuracy: 0.9845 - loss: 0.0269 - val_accuracy: 1.0000 - val_loss: 2.0830e-04 - learning_rate: 5.0000e-04
# Epoch 27/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9463 - loss: 0.1158
# Epoch 27: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 247ms/step - accuracy: 0.9480 - loss: 0.1132 - val_accuracy: 1.0000 - val_loss: 2.2344e-04 - learning_rate: 5.0000e-04
# Epoch 28/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9929 - loss: 0.0348
# Epoch 28: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 235ms/step - accuracy: 0.9920 - loss: 0.0387 - val_accuracy: 1.0000 - val_loss: 1.8624e-04 - learning_rate: 5.0000e-04
# Epoch 29/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9992 - loss: 0.0192
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 29: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 248ms/step - accuracy: 0.9986 - loss: 0.0202 - val_accuracy: 1.0000 - val_loss: 1.7633e-04 - learning_rate: 5.0000e-04
# Epoch 30/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.9865 - loss: 0.0334
# Epoch 30: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 241ms/step - accuracy: 0.9867 - loss: 0.0333 - val_accuracy: 1.0000 - val_loss: 2.3107e-04 - learning_rate: 2.5000e-04
# Restoring model weights from the end of the best epoch: 25.
#
# ============================================================
# PHASE 2: Fine-tuning (unfreezing base model)
# ============================================================
#
# Unfrozen layers: 9
# Frozen layers: 0
#
# Fine-tuning entire model...
# Epoch 1/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 878ms/step - accuracy: 0.9181 - loss: 0.2162
# Epoch 1: val_accuracy improved from -inf to 1.00000, saving model to best_model_transfer.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.9218 - loss: 0.2087 - val_accuracy: 1.0000 - val_loss: 1.5389e-04 - learning_rate: 1.0000e-05
# Epoch 2/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.9700 - loss: 0.1066
# Epoch 2: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 252ms/step - accuracy: 0.9679 - loss: 0.1107 - val_accuracy: 1.0000 - val_loss: 1.7010e-04 - learning_rate: 1.0000e-05
# Epoch 3/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.9784 - loss: 0.1086
# Epoch 3: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 262ms/step - accuracy: 0.9771 - loss: 0.1134 - val_accuracy: 1.0000 - val_loss: 1.9383e-04 - learning_rate: 1.0000e-05
# Epoch 4/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9455 - loss: 0.1049
# Epoch 4: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 249ms/step - accuracy: 0.9444 - loss: 0.1049 - val_accuracy: 1.0000 - val_loss: 2.2285e-04 - learning_rate: 1.0000e-05
# Epoch 5/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.8813 - loss: 0.3000
# Epoch 5: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 235ms/step - accuracy: 0.8848 - loss: 0.2935 - val_accuracy: 1.0000 - val_loss: 2.0078e-04 - learning_rate: 1.0000e-05
# Epoch 6/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9786 - loss: 0.0790
# Epoch 6: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 247ms/step - accuracy: 0.9794 - loss: 0.0770 - val_accuracy: 1.0000 - val_loss: 1.7591e-04 - learning_rate: 1.0000e-05
# Epoch 7/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.9297 - loss: 0.0900
# Epoch 7: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 257ms/step - accuracy: 0.9318 - loss: 0.0886 - val_accuracy: 1.0000 - val_loss: 1.8294e-04 - learning_rate: 1.0000e-05
# Epoch 8/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9719 - loss: 0.0688
# Epoch 8: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
#
# Epoch 8: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 250ms/step - accuracy: 0.9717 - loss: 0.0688 - val_accuracy: 1.0000 - val_loss: 1.8997e-04 - learning_rate: 1.0000e-05
# Epoch 9/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9831 - loss: 0.1097
# Epoch 9: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 241ms/step - accuracy: 0.9800 - loss: 0.1231 - val_accuracy: 1.0000 - val_loss: 1.8474e-04 - learning_rate: 5.0000e-06
# Epoch 10/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9929 - loss: 0.0472
# Epoch 10: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 250ms/step - accuracy: 0.9920 - loss: 0.0489 - val_accuracy: 1.0000 - val_loss: 1.6776e-04 - learning_rate: 5.0000e-06
# Epoch 11/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.9913 - loss: 0.0520
# Epoch 11: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 258ms/step - accuracy: 0.9912 - loss: 0.0522 - val_accuracy: 1.0000 - val_loss: 1.5997e-04 - learning_rate: 5.0000e-06
# Epoch 12/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.9395 - loss: 0.1543
# Epoch 12: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 263ms/step - accuracy: 0.9409 - loss: 0.1500 - val_accuracy: 1.0000 - val_loss: 1.6652e-04 - learning_rate: 5.0000e-06
# Epoch 13/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.9356 - loss: 0.1209
# Epoch 13: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 265ms/step - accuracy: 0.9359 - loss: 0.1251 - val_accuracy: 1.0000 - val_loss: 1.4632e-04 - learning_rate: 5.0000e-06
# Epoch 14/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9706 - loss: 0.0682
# Epoch 14: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 257ms/step - accuracy: 0.9699 - loss: 0.0725 - val_accuracy: 1.0000 - val_loss: 1.1914e-04 - learning_rate: 5.0000e-06
# Epoch 15/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.9727 - loss: 0.1768
# Epoch 15: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
#
# Epoch 15: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 271ms/step - accuracy: 0.9732 - loss: 0.1722 - val_accuracy: 1.0000 - val_loss: 9.9765e-05 - learning_rate: 5.0000e-06
# Epoch 16/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.9601 - loss: 0.2242
# Epoch 16: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 248ms/step - accuracy: 0.9601 - loss: 0.2197 - val_accuracy: 1.0000 - val_loss: 8.5138e-05 - learning_rate: 2.5000e-06
# Epoch 17/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.9475 - loss: 0.1276
# Epoch 17: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 243ms/step - accuracy: 0.9484 - loss: 0.1277 - val_accuracy: 1.0000 - val_loss: 7.8216e-05 - learning_rate: 2.5000e-06
# Epoch 18/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.9805 - loss: 0.0572
# Epoch 18: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 253ms/step - accuracy: 0.9797 - loss: 0.0594 - val_accuracy: 1.0000 - val_loss: 8.1676e-05 - learning_rate: 2.5000e-06
# Epoch 19/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9764 - loss: 0.0584
# Epoch 19: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 249ms/step - accuracy: 0.9759 - loss: 0.0617 - val_accuracy: 1.0000 - val_loss: 6.9665e-05 - learning_rate: 2.5000e-06
# Epoch 20/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9820 - loss: 0.0775
# Epoch 20: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 237ms/step - accuracy: 0.9797 - loss: 0.0796 - val_accuracy: 1.0000 - val_loss: 5.8920e-05 - learning_rate: 2.5000e-06
# Epoch 21/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9043 - loss: 0.1647
# Epoch 21: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 252ms/step - accuracy: 0.9069 - loss: 0.1606 - val_accuracy: 1.0000 - val_loss: 5.3883e-05 - learning_rate: 2.5000e-06
# Epoch 22/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.9928 - loss: 0.0560
# Epoch 22: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 246ms/step - accuracy: 0.9926 - loss: 0.0573 - val_accuracy: 1.0000 - val_loss: 5.0538e-05 - learning_rate: 2.5000e-06
# Epoch 23/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.9655 - loss: 0.0873
# Epoch 23: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 242ms/step - accuracy: 0.9665 - loss: 0.0855 - val_accuracy: 1.0000 - val_loss: 4.6306e-05 - learning_rate: 2.5000e-06
# Epoch 24/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.9288 - loss: 0.3117
# Epoch 24: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 247ms/step - accuracy: 0.9296 - loss: 0.3070 - val_accuracy: 1.0000 - val_loss: 4.1425e-05 - learning_rate: 2.5000e-06
# Epoch 25/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.9678 - loss: 0.0642
# Epoch 25: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 269ms/step - accuracy: 0.9680 - loss: 0.0640 - val_accuracy: 1.0000 - val_loss: 3.8622e-05 - learning_rate: 2.5000e-06
# Epoch 26/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9912 - loss: 0.0453
# Epoch 26: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 251ms/step - accuracy: 0.9911 - loss: 0.0456 - val_accuracy: 1.0000 - val_loss: 3.8646e-05 - learning_rate: 2.5000e-06
# Epoch 27/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9638 - loss: 0.1175
# Epoch 27: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 251ms/step - accuracy: 0.9621 - loss: 0.1181 - val_accuracy: 1.0000 - val_loss: 3.6907e-05 - learning_rate: 2.5000e-06
# Epoch 28/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.9827 - loss: 0.0944
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
#
# Epoch 28: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 252ms/step - accuracy: 0.9818 - loss: 0.0962 - val_accuracy: 1.0000 - val_loss: 3.7998e-05 - learning_rate: 2.5000e-06
# Epoch 29/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.9408 - loss: 0.5449
# Epoch 29: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 260ms/step - accuracy: 0.9429 - loss: 0.5184 - val_accuracy: 1.0000 - val_loss: 4.1106e-05 - learning_rate: 1.2500e-06
# Epoch 30/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.8845 - loss: 0.2142
# Epoch 30: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 250ms/step - accuracy: 0.8878 - loss: 0.2093 - val_accuracy: 1.0000 - val_loss: 4.1764e-05 - learning_rate: 1.2500e-06
# Epoch 31/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9645 - loss: 0.0719
# Epoch 31: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 252ms/step - accuracy: 0.9628 - loss: 0.0737 - val_accuracy: 1.0000 - val_loss: 4.2736e-05 - learning_rate: 1.2500e-06
# Epoch 32/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9426 - loss: 0.1260
# Epoch 32: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 246ms/step - accuracy: 0.9424 - loss: 0.1276 - val_accuracy: 1.0000 - val_loss: 4.2660e-05 - learning_rate: 1.2500e-06
# Epoch 33/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9864 - loss: 0.0576
# Epoch 33: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 246ms/step - accuracy: 0.9860 - loss: 0.0582 - val_accuracy: 1.0000 - val_loss: 4.2755e-05 - learning_rate: 1.2500e-06
# Epoch 34/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9796 - loss: 0.0851
# Epoch 34: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 241ms/step - accuracy: 0.9782 - loss: 0.0892 - val_accuracy: 1.0000 - val_loss: 3.9667e-05 - learning_rate: 1.2500e-06
# Epoch 35/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9736 - loss: 0.0607
# Epoch 35: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-07.
#
# Epoch 35: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 249ms/step - accuracy: 0.9733 - loss: 0.0614 - val_accuracy: 1.0000 - val_loss: 3.5253e-05 - learning_rate: 1.2500e-06
# Epoch 36/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9863 - loss: 0.0368
# Epoch 36: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 247ms/step - accuracy: 0.9866 - loss: 0.0377 - val_accuracy: 1.0000 - val_loss: 3.7965e-05 - learning_rate: 6.2500e-07
# Epoch 37/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 1.0000 - loss: 0.0184
# Epoch 37: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 254ms/step - accuracy: 1.0000 - loss: 0.0184 - val_accuracy: 1.0000 - val_loss: 3.6878e-05 - learning_rate: 6.2500e-07
# Epoch 38/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9965 - loss: 0.0293
# Epoch 38: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 251ms/step - accuracy: 0.9960 - loss: 0.0301 - val_accuracy: 1.0000 - val_loss: 3.5958e-05 - learning_rate: 6.2500e-07
# Epoch 39/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9809 - loss: 0.0527
# Epoch 39: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 248ms/step - accuracy: 0.9794 - loss: 0.0575 - val_accuracy: 1.0000 - val_loss: 3.6101e-05 - learning_rate: 6.2500e-07
# Epoch 40/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.9113 - loss: 0.1958
# Epoch 40: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 262ms/step - accuracy: 0.9155 - loss: 0.1873 - val_accuracy: 1.0000 - val_loss: 3.6430e-05 - learning_rate: 6.2500e-07
# Epoch 41/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.9637 - loss: 0.0770
# Epoch 41: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 241ms/step - accuracy: 0.9634 - loss: 0.0784 - val_accuracy: 1.0000 - val_loss: 3.6516e-05 - learning_rate: 6.2500e-07
# Epoch 42/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9908 - loss: 0.0241
# Epoch 42: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-07.
#
# Epoch 42: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 246ms/step - accuracy: 0.9908 - loss: 0.0243 - val_accuracy: 1.0000 - val_loss: 3.6043e-05 - learning_rate: 6.2500e-07
# Epoch 43/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.9657 - loss: 0.0754
# Epoch 43: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 255ms/step - accuracy: 0.9668 - loss: 0.0771 - val_accuracy: 1.0000 - val_loss: 3.9614e-05 - learning_rate: 3.1250e-07
# Epoch 44/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9830 - loss: 0.0505
# Epoch 44: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 231ms/step - accuracy: 0.9820 - loss: 0.0532 - val_accuracy: 1.0000 - val_loss: 4.0400e-05 - learning_rate: 3.1250e-07
# Epoch 45/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.9809 - loss: 0.0835
# Epoch 45: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 253ms/step - accuracy: 0.9801 - loss: 0.0843 - val_accuracy: 1.0000 - val_loss: 3.8546e-05 - learning_rate: 3.1250e-07
# Epoch 46/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.9695 - loss: 0.0590
# Epoch 46: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 238ms/step - accuracy: 0.9688 - loss: 0.0610 - val_accuracy: 1.0000 - val_loss: 3.5939e-05 - learning_rate: 3.1250e-07
# Epoch 47/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9941 - loss: 0.0572
# Epoch 47: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 242ms/step - accuracy: 0.9938 - loss: 0.0574 - val_accuracy: 1.0000 - val_loss: 3.8446e-05 - learning_rate: 3.1250e-07
# Epoch 48/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9942 - loss: 0.0131
# Epoch 48: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 248ms/step - accuracy: 0.9939 - loss: 0.0138 - val_accuracy: 1.0000 - val_loss: 3.7893e-05 - learning_rate: 3.1250e-07
# Epoch 49/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9846 - loss: 0.0531
# Epoch 49: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-07.
#
# Epoch 49: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 246ms/step - accuracy: 0.9842 - loss: 0.0541 - val_accuracy: 1.0000 - val_loss: 3.8985e-05 - learning_rate: 3.1250e-07
# Epoch 50/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9793 - loss: 0.0897
# Epoch 50: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 249ms/step - accuracy: 0.9779 - loss: 0.0927 - val_accuracy: 1.0000 - val_loss: 4.3885e-05 - learning_rate: 1.5625e-07
# Epoch 51/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.9602 - loss: 0.1146
# Epoch 51: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 257ms/step - accuracy: 0.9602 - loss: 0.1155 - val_accuracy: 1.0000 - val_loss: 4.4600e-05 - learning_rate: 1.5625e-07
# Epoch 52/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.9754 - loss: 0.0746
# Epoch 52: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 239ms/step - accuracy: 0.9758 - loss: 0.0735 - val_accuracy: 1.0000 - val_loss: 4.5563e-05 - learning_rate: 1.5625e-07
# Epoch 53/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.9751 - loss: 0.0702
# Epoch 53: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 256ms/step - accuracy: 0.9733 - loss: 0.0731 - val_accuracy: 1.0000 - val_loss: 4.4719e-05 - learning_rate: 1.5625e-07
# Epoch 54/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9928 - loss: 0.0294
# Epoch 54: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 234ms/step - accuracy: 0.9919 - loss: 0.0315 - val_accuracy: 1.0000 - val_loss: 4.6101e-05 - learning_rate: 1.5625e-07
# Epoch 55/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9747 - loss: 0.1054
# Epoch 55: val_accuracy did not improve from 1.00000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 251ms/step - accuracy: 0.9751 - loss: 0.1040 - val_accuracy: 1.0000 - val_loss: 4.5562e-05 - learning_rate: 1.5625e-07
# Epoch 55: early stopping
# Restoring model weights from the end of the best epoch: 35.
# Training history plot saved to training_history_transfer.png
#
# ============================================================
# Evaluating model...
# ============================================================
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Alexis       1.00      1.00      1.00        10
#      Dimitri       1.00      1.00      1.00         5
#       Pallav       1.00      1.00      1.00        10
#
#     accuracy                           1.00        25
#    macro avg       1.00      1.00      1.00        25
# weighted avg       1.00      1.00      1.00        25
#
# Confusion matrix saved to confusion_matrix_transfer.png
#
# Final model saved to: face_classifier_transfer_final.keras
#
# ============================================================
# Training Complete!
# ============================================================
#
# Generated files:
# 1. best_model_transfer.keras - Best model during training
# 2. face_classifier_transfer_final.keras - Final trained model
# 3. training_history_transfer.png - Training curves
# 4. confusion_matrix_transfer.png - Confusion matrix
